# %%
import spacy

nlp_ner = spacy.load("output/model-best")

content = open("2022-11-23.txt").read()

doc = nlp_ner(content)

spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Deutscher Bundestag</br>Stenografischer Bericht</br>69. Sitzung</br>Berlin, Mittwoch, den 23. November 2022</br>I n h a l t :</br>Wahl der Abgeordneten Hermann Gröhe und </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadine Schön als persönlich stellvertretende
# Mitglieder des Vermittlungsausschusses .
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
#  . . . .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8007 A
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SEITE</span>
# </mark>
# ...
