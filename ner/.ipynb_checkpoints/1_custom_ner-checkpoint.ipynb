# %%
import spacy
import json

file = open("data/Corona2.json", "r")

# read raw file contents
# print(file.read())

# pretty print parsed JSON
data = json.load(file)
print(json.dumps(data, indent=4))
# Out:
# {
#     "examples": [
#         {
#             "id": "18c2f619-f102-452f-ab81-d26f7e283ffe",
# ...
